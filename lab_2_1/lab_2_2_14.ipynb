# %%
# Задание task_02_14.
#
# Выполнил: Малеванный И.Б.
# Группа: ЦИБ-241



s = float(input("Пробег за 1-й день (км.) ="))
p = float(input("На сколько увеличивает пробег (%) ="))
e=s
total = s
count = 1
print("Пробег за 1-й день (км.) =",s)
for i in range(9):
    e += e*(p/100)+0.0001
    total +=e
    count+=1
    print("Пробег за {}-й день (км.) = {} км.".format(count,round(e,1)))

print("Суммарный пробег: {:.1f} км.".format(total))

# --------------
# Пример вывода:
#
# Пробег за 1-й день (км.) = 5
# На сколько увеличивает пробег (%) = 10
# Пробег за 2-й день: 5.5 км.
# Пробег за 3-й день: 6.1 км.
# Пробег за 4-й день: 6.7 км.
# Пробег за 5-й день: 7.3 км.
# Пробег за 6-й день: 8.1 км.
# Пробег за 7-й день: 8.9 км.
# Пробег за 8-й день: 9.7 км.
# Пробег за 9-й день: 10.7 км.
# Пробег за 10-й день: 11.8 км.
# Суммарный пробег: 79.7 км.
# Out:
# Пробег за 1-й день (км.) = 5.0
# Пробег за 2-й день (км.) = 5.5 км.
# Пробег за 3-й день (км.) = 6.1 км.
# Пробег за 4-й день (км.) = 6.7 км.
# Пробег за 5-й день (км.) = 7.3 км.
# Пробег за 6-й день (км.) = 8.1 км.
# Пробег за 7-й день (км.) = 8.9 км.
# Пробег за 8-й день (км.) = 9.7 км.
# Пробег за 9-й день (км.) = 10.7 км.
# Пробег за 10-й день (км.) = 11.8 км.
# Суммарный пробег: 79.7 км.
